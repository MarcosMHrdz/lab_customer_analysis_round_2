# %%
import pandas as pd

# %% [markdown]
# Muestra la forma del marco de datos.
#
# BONIFICACIÓN: coloque todas las transformaciones de datos mencionadas anteriormente en una función.

# %%
df=pd.read_csv(r"C:\Users\marco\OneDrive\Desktop\ironhack\Files\marketing_customer_analysis.csv")
df
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
df.shape
print('Formato del DataFreme',df.shape)
# Out:
# Formato del DataFreme (10910, 26)

# %% [markdown]
# ¿Qué columnas son numéricas?
# ¿Qué columnas son categóricas?

# %%
tipos_de_datos=df.dtypes
tipos_de_datos
# Out:
# Unnamed: 0                         int64
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim          float64
# Months Since Policy Inception      int64
# Number of Open Complaints        float64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# ...

# %%
colimnas_numericas = df.describe(include=['float','int'])
colimnas_numericas
# Out:
#          Unnamed: 0  Customer Lifetime Value        Income  \
# count  10910.000000             10910.000000  10910.000000
# mean    5454.500000              8018.241094  37536.284785
# std     3149.590053              6885.081434  30359.195670
# min        0.000000              1898.007675      0.000000
# 25%     2727.250000              4014.453113      0.000000
# 50%     5454.500000              5771.147235  33813.500000
# 75%     8181.750000              8992.779137  62250.750000
# max    10909.000000             83325.381190  99981.000000
#
#        Monthly Premium Auto  Months Since Last Claim  \
# count          10910.000000             10277.000000
# mean              93.196059                15.149071
# std               34.442532                10.080349
# min               61.000000                 0.000000
# 25%               68.000000                 6.000000
# 50%               83.000000                14.000000
# 75%              109.000000                23.000000
# ...

# %%
colimnas_categoricas = df.describe(include=['object'])
colimnas_categoricas
# Out:
#        Customer       State Response Coverage Education Effective To Date  \
# count     10910       10279    10279    10910     10910             10910
# unique     9134           5        2        3         5                59
# top     ID89933  California       No    Basic  Bachelor           1/10/11
# freq          7        3552     8813     6660      3272               239
#
#        EmploymentStatus Gender Location Code Marital Status    Policy Type  \
# count             10910  10910         10910          10910          10910
# unique                5      2             3              3              3
# top            Employed      F      Suburban        Married  Personal Auto
# freq               6789   5573          6902           6319           8128
#
#              Policy Renew Offer Type Sales Channel  Vehicle Class  \
# count         10910            10910         10910          10288
# unique            9                4             4              6
# ...

# %% [markdown]
# Verificar y tratar con NaNvalores.

# %%
df_limpiado = df.dropna()
df_limpiado
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 10             10  HG93801     Arizona              5154.764074       No
# 13             13  KR82385  California              5454.587929       No
# 16             16  FH51383  California              5326.677654       No
# ...           ...      ...         ...                      ...      ...
# 10902       10902  PP30874  California              3579.023825       No
# 10903       10903  SU71163     Arizona              2771.663013       No
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        Coverage             Education Effective To Date EmploymentStatus  \
# ...

# %%
valores_nun = df_limpiado.isna().sum()
valores_nun
# Out:
# Unnamed: 0                       0
# Customer                         0
# State                            0
# Customer Lifetime Value          0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Renew Offer Type                 0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# Vehicle Type                     0
# dtype: int64

# %%
valores_nun1 = df_limpiado.isnull()
valores_nun1
# Out:
#        Unnamed: 0  Customer  State  Customer Lifetime Value  Response  \
# 2           False     False  False                    False     False
# 3           False     False  False                    False     False
# 10          False     False  False                    False     False
# 13          False     False  False                    False     False
# 16          False     False  False                    False     False
# ...           ...       ...    ...                      ...       ...
# 10902       False     False  False                    False     False
# 10903       False     False  False                    False     False
# 10904       False     False  False                    False     False
# 10906       False     False  False                    False     False
# 10908       False     False  False                    False     False
#
#        Coverage  Education  Effective To Date  EmploymentStatus  Gender  ...  \
# ...

# %%
df["Effective To Date"] = pd.to_datetime(df["Effective To Date"])

# Extraer el mes y guardarlo en una columna separada
df["Month"] = df["Effective To Date"].dt.month

# Filtrar los datos para mostrar solo el primer trimestre (enero, febrero y marzo)
filtered_data = df[df["Month"].isin([1, 2, 3])]

print(filtered_data)
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
def analisis_consumidor(path):
    pd=pd.read_csv(path)
    forma=df.shape
    columnas=list(pd.colimns)
    pd1=pd1.rename=('un')
